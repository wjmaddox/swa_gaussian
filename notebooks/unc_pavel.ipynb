# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # In / Out-of-Domain Data
# ## CIFAR-5 Entropy

# %%
def plot_entropy(myax, inclass, outclass, label):
    #plt.figure(figsize=(12, 7))
    myax.set_title(str(label), fontsize=12)
    myax.set_xscale('log')
    bins = 10 ** np.linspace(-8, 0.5, 30)
    myax.hist(inclass, bins=bins, color='red')
    myax.hist(outclass, bins=bins, color='black', alpha=0.3)
    myax.set_ylim((0, 3000))
    #myax.show()

# %% [markdown]
# ### VGG

# %%
swag_cov_inclass = np.load('../unc_files/c10/vgg/swag/unc_cov_split1.npz')
swag_cov_outclass = np.load('../unc_files/c10/vgg/swag/unc_cov_split0.npz')
swag_inclass = np.load('../unc_files/c10/vgg/swag/unc_split1.npz')
swag_outclass = np.load('../unc_files/c10/vgg/swag/unc_split0.npz')
swa_inclass = np.load('../unc_files/c10/vgg/swag/unc_swa_split1.npz')
swa_outclass = np.load('../unc_files/c10/vgg/swag/unc_swa_split0.npz')
sgd_inclass = np.load('../unc_files/c10/vgg/swag/unc_sgd_split1.npz')
sgd_outclass = np.load('../unc_files/c10/vgg/swag/unc_sgd_split0.npz')

# %%
f, axarr = plt.subplots(2, 2, figsize=(12, 12))
plt.title('Entropy Distributions')
plot_entropy(axarr[0, 0], swag_cov_inclass['entropies'], swag_cov_outclass['entropies'], 'SWAG-Cov')
plot_entropy(axarr[0, 1], swag_inclass['entropies'], swag_outclass['entropies'], 'SWAG-Diag')
plot_entropy(axarr[1, 0], swa_inclass['entropies'], swa_outclass['entropies'], 'SWA')
plot_entropy(axarr[1, 1], sgd_inclass['entropies'], sgd_outclass['entropies'], 'SGD')
axarr[0, 0].set(ylabel='Count')
axarr[1,0].set(ylabel='Count', xlabel='Entropy')
axarr[0, 0].set(xlabel='Entropy')
f.suptitle("CIFAR-10, VGG", fontsize=18)
# Out:
# Text(0.5,0.98,'CIFAR-10, VGG')

# %% [markdown]
# **Dropout**

# %%
swag_cov_inclass = np.load('../unc_files/c10/vgg/swag/unc_cov_drop_split1.npz')
swag_cov_outclass = np.load('../unc_files/c10/vgg/swag/unc_cov_drop_split0.npz')
swag_inclass = np.load('../unc_files/c10/vgg/swag/unc_drop_split1.npz')
swag_outclass = np.load('../unc_files/c10/vgg/swag/unc_drop_split0.npz')
swa_inclass = np.load('../unc_files/c10/vgg/swag/unc_swadrop_split1.npz')
swa_outclass = np.load('../unc_files/c10/vgg/swag/unc_swadrop_split0.npz')
sgd_inclass = np.load('../unc_files/c10/vgg/swag/unc_drop_split1.npz')
sgd_outclass = np.load('../unc_files/c10/vgg/swag/unc_drop_split0.npz')

# %%
f, axarr = plt.subplots(2, 2, figsize=(12, 12))
plt.title('Entropy Distributions')
plot_entropy(axarr[0, 0], swag_cov_inclass['entropies'], swag_cov_outclass['entropies'], 'SWAG-Cov')
plot_entropy(axarr[0, 1], swag_inclass['entropies'], swag_outclass['entropies'], 'SWAG-Diag')
plot_entropy(axarr[1, 0], swa_inclass['entropies'], swa_outclass['entropies'], 'SWA')
plot_entropy(axarr[1, 1], sgd_inclass['entropies'], sgd_outclass['entropies'], 'SGD')
axarr[0, 0].set(ylabel='Count')
axarr[1,0].set(ylabel='Count', xlabel='Entropy')
axarr[0, 0].set(xlabel='Entropy')
f.suptitle("CIFAR-10, VGG, Dropout", fontsize=18)
# Out:
# Text(0.5,0.98,'CIFAR-10, VGG, Dropout')

# %% [markdown]
# ### ResNet

# %%
swag_cov_inclass = np.load('../unc_files/c10/resnet110/swag/unc_cov_split1.npz')
swag_cov_outclass = np.load('../unc_files/c10/resnet110/swag/unc_cov_split0.npz')
swag_inclass = np.load('../unc_files/c10/resnet110/swag/unc_split1.npz')
swag_outclass = np.load('../unc_files/c10/resnet110/swag/unc_split0.npz')
swa_inclass = np.load('../unc_files/c10/resnet110/swag/unc_swa_split1.npz')
swa_outclass = np.load('../unc_files/c10/resnet110/swag/unc_swa_split0.npz')
sgd_inclass = np.load('../unc_files/c10/resnet110/swag/unc_sgd_split1.npz')
sgd_outclass = np.load('../unc_files/c10/resnet110/swag/unc_sgd_split0.npz')

# %%
# plt.close()
# plt.figure(figsize=(6, 12))
f, axarr = plt.subplots(2, 2, figsize=(12, 12))
#f.xscale('log')
plt.title('Entropy Distributions')
plot_entropy(axarr[0, 0], swag_cov_inclass['entropies'], swag_cov_outclass['entropies'], 'SWAG-Cov')
plot_entropy(axarr[0, 1], swag_inclass['entropies'], swag_outclass['entropies'], 'SWAG-Diag')
plot_entropy(axarr[1, 0], swa_inclass['entropies'], swa_outclass['entropies'], 'SWA')
plot_entropy(axarr[1, 1], sgd_inclass['entropies'], sgd_outclass['entropies'], 'SGD')
axarr[0, 0].set(ylabel='Count')
# axarr[1,0].set(ylabel='Count', xlabel='Entropy')
axarr[0, 0].set(xlabel='Entropy')
f.suptitle("CIFAR-10, ResNet", fontsize=18)

# f.subplots_adjust(hspace=0.8)
# f.set_title("CIFAR-10, ResNet-110")
#plt.show()
#plt.savefig('../plots/cifar10_entropy_dists-1214.pdf')
# Out:
# Text(0.5,0.98,'CIFAR-10, ResNet')

# %% [markdown]
# ### WRN

# %%
swag_cov_inclass = np.load('../unc_files/c10/wrn/swag/unc_cov_split1.npz')
swag_cov_outclass = np.load('../unc_files/c10/wrn/swag/unc_cov_split0.npz')
swag_inclass = np.load('../unc_files/c10/wrn/swag/unc_split1.npz')
swag_outclass = np.load('../unc_files/c10/wrn/swag/unc_split0.npz')
swa_inclass = np.load('../unc_files/c10/wrn/swag/unc_swa_split1.npz')
swa_outclass = np.load('../unc_files/c10/wrn/swag/unc_swa_split0.npz')
sgd_inclass = np.load('../unc_files/c10/wrn/swag/unc_sgd_split1.npz')
sgd_outclass = np.load('../unc_files/c10/wrn/swag/unc_sgd_split0.npz')

# %%
# plt.close()
# plt.figure(figsize=(6, 12))
f, axarr = plt.subplots(2, 2, figsize=(12, 12))
#f.xscale('log')
plt.title('Entropy Distributions')
plot_entropy(axarr[0, 0], swag_cov_inclass['entropies'], swag_cov_outclass['entropies'], 'SWAG-Cov')
plot_entropy(axarr[0, 1], swag_inclass['entropies'], swag_outclass['entropies'], 'SWAG-Diag')
plot_entropy(axarr[1, 0], swa_inclass['entropies'], swa_outclass['entropies'], 'SWA')
plot_entropy(axarr[1, 1], sgd_inclass['entropies'], sgd_outclass['entropies'], 'SGD')
axarr[0, 0].set(ylabel='Count')
# axarr[1,0].set(ylabel='Count', xlabel='Entropy')
axarr[0, 0].set(xlabel='Entropy')
f.suptitle("CIFAR-10, WRN", fontsize=18)

# f.subplots_adjust(hspace=0.8)
# f.set_title("CIFAR-10, ResNet-110")
#plt.show()
#plt.savefig('../plots/cifar10_entropy_dists-1214.pdf')
# Out:
# Text(0.5,0.98,'CIFAR-10, WRN')

# %% [markdown]
# # Calibration

# %%
def compute_accuracy_by_entropy(entropy, preds, labels, bins=None):
    if bins is None:
        bins = np.percentile(entropy, np.arange(100))
    digitized = np.digitize(entropy, bins)
    accuracy = [np.sum(preds[digitized==i]==labels[digitized==i])/np.sum(digitized==i) for i in range(1, len(bins))]
    return accuracy, bins

# %%
def ece_loss(outputs, labels, bins=np.arange(0.1, 1.05, 0.05)):
    confidences = np.max(outputs, 1)
    predictions = np.argmax(outputs,1)
    bin_lowers = bins[:-1]
    bin_uppers = bins[1:]
    
    accuracies = predictions == labels

    #ece = Variable(torch.zeros(1)).type_as(confidences)
    ece = 0.0
    for bin_lower, bin_upper in zip(bin_lowers, bin_uppers):
        # Calculated |confidence - accuracy| in each bin
        in_bin = (confidences > bin_lower) * (confidences < bin_upper)
        prop_in_bin = in_bin.mean()
        if prop_in_bin > 0:
            accuracy_in_bin = accuracies[in_bin].mean()
            avg_confidence_in_bin = confidences[in_bin].mean()
            ece += np.abs(avg_confidence_in_bin-accuracy_in_bin) * prop_in_bin

    return ece

# %%
def NLL(outputs, labels):
    labels = labels.astype(int)
    idx = (np.arange(labels.size), labels)
    ps = outputs[idx]
    return -np.sum(np.log(ps))

# %%
import os
os.sys.path.append("../experiments/uncertainty/")
from temp_scaling import optimal_temp_scale, rescale_temp
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## CIFAR-10 -> STL

# %% [markdown]
# ### VGG-16

# %%
swag_cov = np.load('../unc_files/c10/vgg/run1/unc_swagcov_stl.npz')
swag = np.load('../unc_files/c10/vgg/run1/unc_swagdiag_stl.npz')
swa = np.load('../unc_files/c10/vgg/run1/unc_swa_stl.npz')
sgd = np.load('../unc_files/c10/vgg/run1/unc_sgd_stl.npz')
swa_drop = np.load('../unc_files/c10/vgg/run1/unc_swa_drop_stl.npz')
drop = np.load('../unc_files/c10/vgg/run1/unc_sgd_drop_stl.npz')
swa_val = np.load('../unc_files/c10/vgg/run1/unc_swa_val.npz')
sgd_val = np.load('../unc_files/c10/vgg/run1/unc_sgd_val.npz')

# %%
T_swa, _ = optimal_temp_scale(swa_val["predictions"], swa_val["targets"], lr=1e-3)
T_sgd, _ = optimal_temp_scale(sgd_val["predictions"], sgd_val["targets"], lr=1e-3)
rescaled_swa = rescale_temp(swa["predictions"], T_swa)
# T_sgd=1
rescaled_sgd = rescale_temp(sgd["predictions"], T_sgd)
# Out:
# Before temperature - NLL: 0.001
# After temperature - NLL: 0.001
# Before temperature - NLL: 0.308
# After temperature - NLL: 0.256
# ../experiments/uncertainty/temp_scaling.py:35: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return T.item(), F.softmax(logits / T).data.numpy()

# %%
with_titles = True
print("Accuracy")
if with_titles:
    print("SGD: ", end="")
print(np.mean(np.argmax(sgd["predictions"], axis=1) == sgd["targets"]))
if with_titles:
    print("SWA: ", end="")
print(np.mean(np.argmax(swa["predictions"], axis=1) == swa["targets"]))
if with_titles:
    print("SWAG-Diag: ", end="")
print(np.mean(np.argmax(swag["predictions"], axis=1) == swag["targets"]))
if with_titles:
    print("SWAG-Cov x 0.5: ", end="")
print(np.mean(np.argmax(swag_cov["predictions"], axis=1) == swag_cov["targets"]))
if with_titles:
    print("Dropout: ", end="")
print(np.mean(np.argmax(drop["predictions"], axis=1) == drop["targets"]))
if with_titles:
    print("SWA-Dropout: ", end="")
print(np.mean(np.argmax(swa_drop["predictions"], axis=1) == swa_drop["targets"]))
if with_titles:
    print("SGD-Temp: ", end="")
print("-")
if with_titles:
    print("SWA-Temp: ", end="")
print("-")
if with_titles:
    print("KFAC-Laplace: ", end="")
# print(np.mean(np.argmax(laplace["predictions"], axis=1) == laplace["targets"]))
print("-")
print()
print("ECE")
if with_titles:
    print("SGD: ", end="") 
print("%.3f"%(ece_loss(outputs=sgd["predictions"], labels=sgd["targets"])))
if with_titles:
    print("SWA: ", end="") 
print("%.3f"%(ece_loss(outputs=swa["predictions"], labels=swa["targets"])))
if with_titles:
    print("SWAG-Diag: ", end="") 
print("%.3f"%(ece_loss(outputs=swag["predictions"], labels=swag["targets"])))
if with_titles:
    print("SWAG-Cov x 0.5: ", end="") 
print("%.3f"%(ece_loss(outputs=swag_cov["predictions"], labels=swag_cov["targets"])))
if with_titles:
    print("Dropout: ", end="") 
print("%.3f"%(ece_loss(outputs=drop["predictions"], labels=drop["targets"])))
if with_titles:
    print("SWA-Dropout: ", end="") 
print("%.3f"%(ece_loss(outputs=swa_drop["predictions"], labels=swa_drop["targets"])))
if with_titles:
    print("SGD-Temp: ", end="")
print("%.3f"%(ece_loss(outputs=rescaled_sgd, labels=swa_drop["targets"])))
if with_titles:
    print("SWA-Temp: ", end="")
print("%.3f"%(ece_loss(outputs=rescaled_swa, labels=swa_drop["targets"])))
if with_titles:
    print("KFAC-Laplace: ", end="") 
# print("%.3f"%(ece_loss(outputs=laplace["predictions"], labels=laplace["targets"])))
print("-")
print()
print("NLL")
if with_titles:
    print("SGD: ", end="") 
print("%.3f"%(NLL(outputs=sgd["predictions"], labels=sgd["targets"])))
if with_titles:
    print("SWA: ", end="") 
print("%.3f"%(NLL(outputs=swa["predictions"], labels=swa["targets"])))
if with_titles:
    print("SWAG-Diag: ", end="") 
print("%.3f"%(NLL(outputs=swag["predictions"], labels=swag["targets"])))
if with_titles:
    print("SWAG-Cov x 0.5: ", end="") 
print("%.3f"%(NLL(outputs=swag_cov["predictions"], labels=swag_cov["targets"])))
if with_titles:
    print("Dropout: ", end="") 
print("%.3f"%(NLL(outputs=drop["predictions"], labels=drop["targets"])))
if with_titles:
    print("SWA-Dropout: ", end="") 
print("%.3f"%(NLL(outputs=swa_drop["predictions"], labels=swa_drop["targets"])))
if with_titles:
    print("SGD-Temp: ", end="")
print("%.3f"%(NLL(outputs=rescaled_sgd, labels=swa_drop["targets"])))
if with_titles:
    print("SWA-Temp: ", end="")
print("%.3f"%(NLL(outputs=rescaled_swa, labels=swa_drop["targets"])))
if with_titles:
    print("KFAC-Laplace: ", end="") 
# print("%.3f"%(NLL(outputs=laplace["predictions"], labels=laplace["targets"])))
print("-")
print()
# Out:
# Accuracy
# SGD: 0.289125
# SWA: 0.275375
# SWAG-Diag: 0.39275
# SWAG-Cov x 0.5: 0.39675
# Dropout: 0.263
# SWA-Dropout: 0.264
# SGD-Temp: -
# SWA-Temp: -
# KFAC-Laplace: -
#
# ECE
# SGD: 0.527
# SWA: 0.524
# SWAG-Diag: 0.032
# SWAG-Cov x 0.5: 0.024
# Dropout: 0.522
# SWA-Dropout: 0.478
# SGD-Temp: 0.468
# SWA-Temp: 0.526
# KFAC-Laplace: -
#
# NLL
# SGD: 31674.479
# SWA: 28648.088
# SWAG-Diag: 13653.400
# SWAG-Cov x 0.5: 13618.866
# Dropout: 30737.631
# SWA-Dropout: 26292.307
# SGD-Temp: 25748.047
# SWA-Temp: 28825.097
# KFAC-Laplace: -

# %%
#plt.xscale('log')

acc, bins = compute_accuracy_by_entropy(np.max(swag_cov['predictions'],1), 
                                        np.argmax(swag_cov['predictions'],1), 
                                        swag_cov['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWAG-Cov')

acc, bins = compute_accuracy_by_entropy(np.max(swag['predictions'],1), 
                                        np.argmax(swag['predictions'],1), 
                                        swag['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWAG-Diagonal')

acc, bins = compute_accuracy_by_entropy(np.max(swa['predictions'],1), 
                                        np.argmax(swa['predictions'],1), 
                                        swa['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWA')

acc, bins = compute_accuracy_by_entropy(np.max(sgd['predictions'],1), 
                                        np.argmax(sgd['predictions'],1), 
                                        sgd['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SGD')

acc, bins = compute_accuracy_by_entropy(np.max(swa['predictions'],1), 
                                        np.argmax(swa['predictions'],1), 
                                        swa['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWA')

acc, bins = compute_accuracy_by_entropy(np.max(sgd_drop['predictions'],1), 
                                        np.argmax(sgd_drop['predictions'],1), 
                                        sgd_drop['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SGD-Drop')

acc, bins = compute_accuracy_by_entropy(np.max(swa_drop['predictions'],1), 
                                        np.argmax(swa_drop['predictions'],1), 
                                        swa_drop['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWA-Drop')

acc, bins = compute_accuracy_by_entropy(np.max(rescaled_sgd,1), 
                                        np.argmax(rescaled_sgd,1), 
                                        sgd['targets'],
                                        bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWA-Temp')

acc, bins = compute_accuracy_by_entropy(np.max(rescaled_swa,1), 
                                        np.argmax(rescaled_swa,1), 
                                        swa['targets'],
                                        bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWA-Temp')

plt.plot(np.arange(0.1,1.01,.01), np.arange(0.1,1.01,.01), c='black')

plt.xlabel('Max Probability', fontsize = 16)
plt.ylabel('Accuracy', fontsize = 16)
plt.grid()
plt.legend()
plt.title("CIFAR-10 -> STL, VGG-16")
#plt.savefig('../plots/cifar100_calibration_1219.eps')
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in long_scalars
#   """
# Text(0.5,1,'CIFAR-10 -> STL, VGG-16')

# %% [markdown]
# ## CIFAR-10

# %% [markdown]
# ### VGG-16

# %%
swag_cov = np.load('../unc_files/c10/vgg/swag/unc_cov.npz')
swag = np.load('../unc_files/c10/vgg/swag/unc.npz')
swa = np.load('../unc_files/c10/vgg/swag/unc_swa.npz')
sgd = np.load('../unc_files/c10/vgg/swag/unc_sgd.npz')

# %%
print("Accuracy")
print("SWAG-Diag:", np.mean(np.argmax(swag["predictions"], axis=1) == swag["targets"]))
print("SWAG-Cov:", np.mean(np.argmax(swag_cov["predictions"], axis=1) == swag_cov["targets"]))
print("SWA:", np.mean(np.argmax(swa["predictions"], axis=1) == swa["targets"]))
print("SGD:", np.mean(np.argmax(sgd["predictions"], axis=1) == sgd["targets"]))
print()
print("ECE")
print("SWAG-Diag:", ece_loss(outputs=swag["predictions"], labels=swag["targets"]))
print("SWAG-Cov:", ece_loss(outputs=swag_cov["predictions"], labels=swag_cov["targets"]))
print("SWA:", ece_loss(outputs=swa["predictions"], labels=swa["targets"]))
print("SGD:", ece_loss(outputs=sgd["predictions"], labels=sgd["targets"]))
print()
print("NLL")
print("SWAG-Diag:", NLL(outputs=swag["predictions"], labels=swag["targets"]))
print("SWAG-Cov:", NLL(outputs=swag_cov["predictions"], labels=swag_cov["targets"]))
print("SWA:", NLL(outputs=swa["predictions"], labels=swa["targets"]))
print("SGD:", NLL(outputs=sgd["predictions"], labels=sgd["targets"]))
# Out:
# Accuracy
# SWAG-Diag: 0.9388
# SWAG-Cov: 0.9365
# SWA: 0.9372
# SGD: 0.9317
#
# ECE
# SWAG-Diag: 0.031167365519740135
# SWAG-Cov: 0.017068137040585848
# SWA: 0.04326725863516329
# SGD: 0.0503475933343172
#
# NLL
# SWAG-Diag: 2322.289458096502
# SWAG-Cov: 2036.6968689338423
# SWA: 2785.3283013433906
# SGD: 3483.519669787634

# %%
#plt.xscale('log')


acc, bins = compute_accuracy_by_entropy(np.max(swag_cov['predictions'],1), 
                                        np.argmax(swag_cov['predictions'],1), 
                                        swag_cov['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWAG-Cov')

acc, bins = compute_accuracy_by_entropy(np.max(swag['predictions'],1), 
                                        np.argmax(swag['predictions'],1), 
                                        swag['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWAG-Diagonal')

acc, bins = compute_accuracy_by_entropy(np.max(swa['predictions'],1), 
                                        np.argmax(swa['predictions'],1), 
                                        swa['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWA')

acc, bins = compute_accuracy_by_entropy(np.max(sgd['predictions'],1), 
                                        np.argmax(sgd['predictions'],1), 
                                        sgd['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SGD')

plt.plot(np.arange(0.1,1.01,.01), np.arange(0.1,1.01,.01), c='black')

plt.xlabel('Max Probability', fontsize = 16)
plt.ylabel('Accuracy', fontsize = 16)
plt.grid()
plt.legend()
plt.title("CIFAR-10, VGG-16")
#plt.savefig('../plots/cifar100_calibration_1219.eps')
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in long_scalars
#   """
# Text(0.5,1,'CIFAR-10, VGG-16')

# %% [markdown]
# ### ResNet-110

# %%
swag_cov = np.load('../unc_files/c10/resnet110/swag/unc_cov.npz')
swag = np.load('../unc_files/c10/resnet110/swag/unc.npz')
swa = np.load('../unc_files/c10/resnet110/swag/unc_swa.npz')
sgd = np.load('../unc_files/c10/resnet110/swag/unc_sgd.npz')

# %%
print("Accuracy")
print("SWAG-Diag:", np.mean(np.argmax(swag["predictions"], axis=1) == swag["targets"]))
print("SWAG-Cov:", np.mean(np.argmax(swag_cov["predictions"], axis=1) == swag_cov["targets"]))
print("SWA:", np.mean(np.argmax(swa["predictions"], axis=1) == swa["targets"]))
print("SGD:", np.mean(np.argmax(sgd["predictions"], axis=1) == sgd["targets"]))
print()
print("ECE")
print("SWAG-Diag:", ece_loss(outputs=swag["predictions"], labels=swag["targets"]))
print("SWAG-Cov:", ece_loss(outputs=swag_cov["predictions"], labels=swag_cov["targets"]))
print("SWA:", ece_loss(outputs=swa["predictions"], labels=swa["targets"]))
print("SGD:", ece_loss(outputs=sgd["predictions"], labels=sgd["targets"]))
print()
print("NLL")
print("SWAG-Diag:", NLL(outputs=swag["predictions"], labels=swag["targets"]))
print("SWAG-Cov:", NLL(outputs=swag_cov["predictions"], labels=swag_cov["targets"]))
print("SWA:", NLL(outputs=swa["predictions"], labels=swa["targets"]))
print("SGD:", NLL(outputs=sgd["predictions"], labels=sgd["targets"]))
# Out:
# Accuracy
# SWAG-Diag: 0.9544
# SWAG-Cov: 0.944
# SWA: 0.9569
# SGD: 0.957
#
# ECE
# SWAG-Diag: 0.0109598055666648
# SWAG-Cov: 0.08346008594752702
# SWA: 0.011355590930581035
# SGD: 0.02326709201335913
#
# NLL
# SWAG-Diag: 1372.0267740848317
# SWAG-Cov: 2285.656206684484
# SWA: 1338.3307607025015
# SGD: 1714.0634164035193

# %%
#plt.xscale('log')


acc, bins = compute_accuracy_by_entropy(np.max(swag_cov['predictions'],1), 
                                        np.argmax(swag_cov['predictions'],1), 
                                        swag_cov['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWAG-Cov')

acc, bins = compute_accuracy_by_entropy(np.max(swag['predictions'],1), 
                                        np.argmax(swag['predictions'],1), 
                                        swag['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWAG-Diagonal')

acc, bins = compute_accuracy_by_entropy(np.max(swa['predictions'],1), 
                                        np.argmax(swa['predictions'],1), 
                                        swa['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWA')

acc, bins = compute_accuracy_by_entropy(np.max(sgd['predictions'],1), 
                                        np.argmax(sgd['predictions'],1), 
                                        sgd['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SGD')

plt.plot(np.arange(0.1,1.01,.01), np.arange(0.1,1.01,.01), c='black')

plt.xlabel('Max Probability', fontsize = 16)
plt.ylabel('Accuracy', fontsize = 16)
plt.grid()
plt.legend()
plt.title("CIFAR-10, ResNet-110")
#plt.savefig('../plots/cifar100_calibration_1219.eps')
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in long_scalars
#   """
# Text(0.5,1,'CIFAR-10, ResNet-110')

# %% [markdown]
# ### WRN

# %%
swag_cov = np.load('../unc_files/c10/wrn/swag/unc_cov.npz')
swag_cov05 = np.load('../unc_files/c10/wrn/swag/unc_swagcov.npz')
swag = np.load('../unc_files/c10/wrn/swag/unc.npz')
swa = np.load('../unc_files/c10/wrn/swag/unc_swa.npz')
sgd = np.load('../unc_files/c10/wrn/swag/unc_sgd.npz')
drop = np.load('../unc_files/c10/wrn/swag/unc_sgd_drop.npz')
swa_drop = np.load('../unc_files/c10/wrn/swag/unc_swa_drop.npz')
# swag_drop = np.load('../unc_files/c100/wrn/swag/unc_swagdrop001.npz')
# swa_drop = np.load('../unc_files/c100/wrn/swag/unc_swadrop001.npz')

# %%
swa_val = np.load('../unc_files/c10/wrn/swag/swa_val.npz')
sgd_val = np.load('../unc_files/c10/wrn/swag/sgd_val.npz')
T_swa, rescaled_swa = optimal_temp_scale(swa_val["predictions"], swa_val["targets"])
T_sgd, rescaled_sgd = optimal_temp_scale(sgd_val["predictions"], sgd_val["targets"])#, max_iter=1, lr=1e-5)
rescaled_swa = rescale_temp(swa["predictions"], T_swa)
# T_sgd=1
rescaled_sgd = rescale_temp(sgd["predictions"], T_sgd)
# Out:
# Before temperature - NLL: 0.110
# After temperature - NLL: 0.114
# Before temperature - NLL: 0.145
# After temperature - NLL: 0.138
# ../experiments/uncertainty/temp_scaling.py:35: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return T.item(), F.softmax(logits / T).data.numpy()

# %%
with_titles = False
print("Accuracy")
if with_titles:
    print("SGD: ", end="")
print(np.mean(np.argmax(sgd["predictions"], axis=1) == sgd["targets"]))
if with_titles:
    print("SWA: ", end="")
print(np.mean(np.argmax(swa["predictions"], axis=1) == swa["targets"]))
if with_titles:
    print("SWAG-Diag: ", end="")
print(np.mean(np.argmax(swag["predictions"], axis=1) == swag["targets"]))
if with_titles:
    print("SWAG-Cov x 0.5: ", end="")
print(np.mean(np.argmax(swag_cov05["predictions"], axis=1) == swag_cov05["targets"]))
# print("-")
if with_titles:
    print("Dropout: ", end="")
print(np.mean(np.argmax(drop["predictions"], axis=1) == drop["targets"]))
if with_titles:
    print("SWA-Dropout: ", end="")
print(np.mean(np.argmax(swa_drop["predictions"], axis=1) == swa_drop["targets"]))
if with_titles:
    print("SGD-Temp: ", end="")
print("-")
if with_titles:
    print("SWA-Temp: ", end="")
print("-")
if with_titles:
    print("KFAC-Laplace: ", end="")
# print(np.mean(np.argmax(laplace["predictions"], axis=1) == laplace["targets"]))
print("-")
print()
print("ECE")
if with_titles:
    print("SGD: ", end="") 
print("%.3f"%(ece_loss(outputs=sgd["predictions"], labels=sgd["targets"])))
if with_titles:
    print("SWA: ", end="") 
print("%.3f"%(ece_loss(outputs=swa["predictions"], labels=swa["targets"])))
if with_titles:
    print("SWAG-Diag: ", end="") 
print("%.3f"%(ece_loss(outputs=swag["predictions"], labels=swag["targets"])))
if with_titles:
    print("SWAG-Cov x 0.5: ", end="") 
print("%.3f"%(ece_loss(outputs=swag_cov05["predictions"], labels=swag_cov05["targets"])))
# print("-")
if with_titles:
    print("Dropout: ", end="") 
print("%.3f"%(ece_loss(outputs=drop["predictions"], labels=drop["targets"])))
if with_titles:
    print("SWA-Dropout: ", end="") 
print("%.3f"%(ece_loss(outputs=swa_drop["predictions"], labels=swa_drop["targets"])))
if with_titles:
    print("SGD-Temp: ", end="")
print("%.3f"%(ece_loss(outputs=rescaled_sgd, labels=swa_drop["targets"])))
if with_titles:
    print("SWA-Temp: ", end="")
print("%.3f"%(ece_loss(outputs=rescaled_swa, labels=swa_drop["targets"])))
if with_titles:
    print("KFAC-Laplace: ", end="") 
# print("%.3f"%(ece_loss(outputs=laplace["predictions"], labels=laplace["targets"])))
print("-")
print()
print("NLL")
if with_titles:
    print("SGD: ", end="") 
print("%.3f"%(NLL(outputs=sgd["predictions"], labels=sgd["targets"])))
if with_titles:
    print("SWA: ", end="") 
print("%.3f"%(NLL(outputs=swa["predictions"], labels=swa["targets"])))
if with_titles:
    print("SWAG-Diag: ", end="") 
print("%.3f"%(NLL(outputs=swag["predictions"], labels=swag["targets"])))
if with_titles:
    print("SWAG-Cov x 0.5: ", end="") 
print("%.3f"%(NLL(outputs=swag_cov05["predictions"], labels=swag_cov05["targets"])))
# print("-")
if with_titles:
    print("Dropout: ", end="") 
print("%.3f"%(NLL(outputs=drop["predictions"], labels=drop["targets"])))
if with_titles:
    print("SWA-Dropout: ", end="") 
print("%.3f"%(NLL(outputs=swa_drop["predictions"], labels=swa_drop["targets"])))
if with_titles:
    print("SGD-Temp: ", end="")
print("%.3f"%(NLL(outputs=rescaled_sgd, labels=swa_drop["targets"])))
if with_titles:
    print("SWA-Temp: ", end="")
print("%.3f"%(NLL(outputs=rescaled_swa, labels=swa_drop["targets"])))
if with_titles:
    print("KFAC-Laplace: ", end="") 
# print("%.3f"%(NLL(outputs=laplace["predictions"], labels=laplace["targets"])))
print("-")
print()
# Out:
# Accuracy
# 0.9651
# 0.9641
# 0.9635
# 0.9622
# 0.962
# 0.9627
# -
# -
# -
#
# ECE
# 0.017
# 0.008
# 0.005
# 0.009
# 0.020
# 0.011
# 0.014
# 0.020
# -
#
# NLL
# 1299.126
# 1074.509
# 1079.265
# 1131.157
# 1409.819
# 1123.656
# 1270.099
# 1157.358
# -

# %%
print("Accuracy")
print("SWAG-Diag:", np.mean(np.argmax(swag["predictions"], axis=1) == swag["targets"]))
print("SWAG-Cov:", np.mean(np.argmax(swag_cov["predictions"], axis=1) == swag_cov["targets"]))
print("SWA:", np.mean(np.argmax(swa["predictions"], axis=1) == swa["targets"]))
print("SGD:", np.mean(np.argmax(sgd["predictions"], axis=1) == sgd["targets"]))
print()
print("ECE")
print("SWAG-Diag:", ece_loss(outputs=swag["predictions"], labels=swag["targets"]))
print("SWAG-Cov:", ece_loss(outputs=swag_cov["predictions"], labels=swag_cov["targets"]))
print("SWA:", ece_loss(outputs=swa["predictions"], labels=swa["targets"]))
print("SGD:", ece_loss(outputs=sgd["predictions"], labels=sgd["targets"]))
print()
print("NLL")
print("SWAG-Diag:", NLL(outputs=swag["predictions"], labels=swag["targets"]))
print("SWAG-Cov:", NLL(outputs=swag_cov["predictions"], labels=swag_cov["targets"]))
print("SWA:", NLL(outputs=swa["predictions"], labels=swa["targets"]))
print("SGD:", NLL(outputs=sgd["predictions"], labels=sgd["targets"]))
# Out:
# Accuracy
# SWAG-Diag: 0.9635
# SWAG-Cov: 0.9574
# SWA: 0.9641
# SGD: 0.9651
#
# ECE
# SWAG-Diag: 0.00533764938572747
# SWAG-Cov: 0.04146993807886851
# SWA: 0.008481935130059676
# SGD: 0.016632383081316947
#
# NLL
# SWAG-Diag: 1079.2654746788098
# SWAG-Cov: 1528.8133106424268
# SWA: 1074.5093025399703
# SGD: 1299.1258785952498

# %%
#plt.xscale('log')


acc, bins = compute_accuracy_by_entropy(np.max(swag_cov['predictions'],1), 
                                        np.argmax(swag_cov['predictions'],1), 
                                        swag_cov['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWAG-Cov')

acc, bins = compute_accuracy_by_entropy(np.max(swag['predictions'],1), 
                                        np.argmax(swag['predictions'],1), 
                                        swag['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWAG-Diagonal')

acc, bins = compute_accuracy_by_entropy(np.max(swa['predictions'],1), 
                                        np.argmax(swa['predictions'],1), 
                                        swa['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWA')

acc, bins = compute_accuracy_by_entropy(np.max(sgd['predictions'],1), 
                                        np.argmax(sgd['predictions'],1), 
                                        sgd['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SGD')

plt.plot(np.arange(0.1,1.01,.01), np.arange(0.1,1.01,.01), c='black')

plt.xlabel('Max Probability', fontsize = 16)
plt.ylabel('Accuracy', fontsize = 16)
plt.grid()
plt.legend()
plt.title("CIFAR-10, WRN", fontsize=14)
#plt.savefig('../plots/cifar100_calibration_1219.eps')
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in long_scalars
#   """
# Text(0.5,1,'CIFAR-10, WRN')

# %% [markdown]
# ## CIFAR100

# %% [markdown]
# ### VGG-16

# %%
swag_cov = np.load('../unc_files/c100/vgg/swag/unc_cov.npz')
swag_cov05 = np.load('../unc_files/c100/vgg/swag/unc_cov_scale05.npz')
swag = np.load('../unc_files/c100/vgg/swag/unc.npz')
swag12 = np.load('../unc_files/c100/vgg/swag/unc_scale12.npz')
swag13 = np.load('../unc_files/c100/vgg/swag/unc_scale13.npz')
swa = np.load('../unc_files/c100/vgg/swag/unc_swa.npz')
sgd = np.load('../unc_files/c100/vgg/swag/unc_sgd.npz')
drop = np.load('../unc_files/c100/vgg/swag/unc_drop.npz')
swa_drop = np.load('../unc_files/c100/vgg/swag/unc_swa_drop.npz')
swag_drop = np.load('../unc_files/c100/vgg/swag/unc_swag_drop.npz')
laplace = np.load('../unc_files/c100/vgg/swag/unc_laplace.npz')

# %%
print("Accuracy")
print("SWAG-Diag:", np.mean(np.argmax(swag["predictions"], axis=1) == swag["targets"]))
print("SWAG-Diag x 1.3:", np.mean(np.argmax(swag12["predictions"], axis=1) == swag12["targets"]))
print("SWAG-Diag x 1.2:", np.mean(np.argmax(swag13["predictions"], axis=1) == swag13["targets"]))
print("SWAG-Cov x 0.5:", np.mean(np.argmax(swag_cov["predictions"], axis=1) == swag_cov["targets"]))
print("SWAG-Cov:", np.mean(np.argmax(swag_cov05["predictions"], axis=1) == swag_cov05["targets"]))
print("SWA:", np.mean(np.argmax(swa["predictions"], axis=1) == swa["targets"]))
print("SGD:", np.mean(np.argmax(sgd["predictions"], axis=1) == sgd["targets"]))
print("Dropout:", np.mean(np.argmax(drop["predictions"], axis=1) == drop["targets"]))
print("SWA-Dropout:", np.mean(np.argmax(swa_drop["predictions"], axis=1) == swa_drop["targets"]))
print("SWAG-Dropout:", np.mean(np.argmax(swag_drop["predictions"], axis=1) == swag_drop["targets"]))
print("KFAC-Laplace:", np.mean(np.argmax(laplace["predictions"], axis=1) == laplace["targets"]))
print()
print("ECE")
print("SWAG-Diag:", ece_loss(outputs=swag["predictions"], labels=swag["targets"]))
print("SWAG-Diag x 1.3:", ece_loss(outputs=swag12["predictions"], labels=swag12["targets"]))
print("SWAG-Diag x 1.2:", ece_loss(outputs=swag13["predictions"], labels=swag13["targets"]))
print("SWAG-Cov:", ece_loss(outputs=swag_cov["predictions"], labels=swag_cov["targets"]))
print("SWAG-Cov x 0.5:", ece_loss(outputs=swag_cov05["predictions"], labels=swag_cov05["targets"]))
print("SWA:", ece_loss(outputs=swa["predictions"], labels=swa["targets"]))
print("SGD:", ece_loss(outputs=sgd["predictions"], labels=sgd["targets"]))
print("Dropout:", ece_loss(outputs=drop["predictions"], labels=drop["targets"]))
print("SWA-Dropout:", ece_loss(outputs=swa_drop["predictions"], labels=swa_drop["targets"]))
print("SWAG-Dropout:", ece_loss(outputs=swag_drop["predictions"], labels=swag_drop["targets"]))
print("KFAC-Laplace:", ece_loss(outputs=laplace["predictions"], labels=laplace["targets"]))
print()
print("NLL")
print("SWAG-Diag:", NLL(outputs=swag["predictions"], labels=swag["targets"]))
print("SWAG-Diag x 1.3:", NLL(outputs=swag12["predictions"], labels=swag12["targets"]))
print("SWAG-Diag x 1.2:", NLL(outputs=swag13["predictions"], labels=swag13["targets"]))
print("SWAG-Cov:", NLL(outputs=swag_cov["predictions"], labels=swag_cov["targets"]))
print("SWAG-Cov x 0.5:", NLL(outputs=swag_cov05["predictions"], labels=swag_cov05["targets"]))
print("SWA:", NLL(outputs=swa["predictions"], labels=swa["targets"]))
print("SGD:", NLL(outputs=sgd["predictions"], labels=sgd["targets"]))
print("Dropout:", NLL(outputs=drop["predictions"], labels=drop["targets"]))
print("SWA-Dropout:", NLL(outputs=swa_drop["predictions"], labels=swa_drop["targets"]))
print("SWAG-Dropout:", NLL(outputs=swag_drop["predictions"], labels=swag_drop["targets"]))
print("KFAC-Laplace:", NLL(outputs=laplace["predictions"], labels=laplace["targets"]))
# Out:
# Accuracy
# SWAG-Diag: 0.7462
# SWAG-Diag x 1.3: 0.7472
# SWAG-Diag x 1.2: 0.7467
# SWAG-Cov x 0.5: 0.7452
# SWAG-Cov: 0.7483
# SWA: 0.7397
# SGD: 0.7299
# Dropout: 0.7159
# SWA-Dropout: 0.7269
# SWAG-Dropout: 0.7257
# KFAC-Laplace: 0.729
#
# ECE
# SWAG-Diag: 0.08399466713542329
# SWAG-Diag x 1.3: 0.06008853953501032
# SWAG-Diag x 1.2: 0.04818627897703439
# SWAG-Cov: 0.07214190289361345
# SWAG-Cov x 0.5: 0.04376025616836768
# SWA: 0.15682532907649877
# SGD: 0.185251970847696
# Dropout: 0.08677970982869959
# SWA-Dropout: 0.09028242880017627
# SWAG-Dropout: 0.038790302758473554
# KFAC-Laplace: 0.13660889962783915
#
# NLL
# SWAG-Diag: 10109.145410158415
# SWAG-Diag x 1.3: 9648.83392521133
# SWAG-Diag x 1.2: 9479.441321660155
# SWAG-Cov: 9610.08687310402
# SWAG-Cov x 0.5: 9420.11769852931
# SWA: 12812.514649487013
# SGD: 17318.23517984058
# Dropout: 11953.626938348036
# SWA-Dropout: 11197.412901353891
# SWAG-Dropout: 10350.25541035318
# KFAC-Laplace: 14031.223974981122

# %%
#plt.xscale('log')


# acc, bins = compute_accuracy_by_entropy(np.max(swag_cov['predictions'],1), 
#                                         np.argmax(swag_cov['predictions'],1), 
#                                         swag_cov['targets'],
#                                        bins = np.arange(0.1, 1.05, 0.05))
# plt.plot(bins[1:], acc, label='SWAG-Cov')

acc, bins = compute_accuracy_by_entropy(np.max(swag_cov05['predictions'],1), 
                                        np.argmax(swag_cov05['predictions'],1), 
                                        swag_cov05['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWAG-Cov x 0.5')

acc, bins = compute_accuracy_by_entropy(np.max(swag['predictions'],1), 
                                        np.argmax(swag['predictions'],1), 
                                        swag['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWAG-Diagonal')

# acc, bins = compute_accuracy_by_entropy(np.max(swag12['predictions'],1), 
#                                         np.argmax(swag12['predictions'],1), 
#                                         swag12['targets'],
#                                        bins = np.arange(0.1, 1.05, 0.05))
# plt.plot(bins[1:], acc, '--c', label='SWAG-Diagonal x 1.2')

# acc, bins = compute_accuracy_by_entropy(np.max(swag13['predictions'],1), 
#                                         np.argmax(swag13['predictions'],1), 
#                                         swag13['targets'],
#                                        bins = np.arange(0.1, 1.05, 0.05))
# plt.plot(bins[1:], acc, '--m', label='SWAG-Diagonal x 1.3')

acc, bins = compute_accuracy_by_entropy(np.max(swa['predictions'],1), 
                                        np.argmax(swa['predictions'],1), 
                                        swa['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWA')


acc, bins = compute_accuracy_by_entropy(np.max(sgd['predictions'],1), 
                                        np.argmax(sgd['predictions'],1), 
                                        sgd['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SGD')

# acc, bins = compute_accuracy_by_entropy(np.max(drop['predictions'],1), 
#                                         np.argmax(drop['predictions'],1), 
#                                         drop['targets'],
#                                        bins = np.arange(0.1, 1.05, 0.05))
# plt.plot(bins[1:], acc, '--k*', label='Dropout')

acc, bins = compute_accuracy_by_entropy(np.max(swa_drop['predictions'],1), 
                                        np.argmax(swa_drop['predictions'],1), 
                                        swa_drop['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, '--r*', label='SWA-Dropout')

# acc, bins = compute_accuracy_by_entropy(np.max(swag_drop['predictions'],1), 
#                                         np.argmax(swag_drop['predictions'],1), 
#                                         swag_drop['targets'],
#                                        bins = np.arange(0.1, 1.05, 0.05))
# plt.plot(bins[1:], acc, '--g*', label='SWAG-Dropout')

acc, bins = compute_accuracy_by_entropy(np.max(laplace['predictions'],1), 
                                        np.argmax(laplace['predictions'],1), 
                                        laplace['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='KFAC-Laplace')

plt.plot(np.arange(0.1,1.01,.01), np.arange(0.1,1.01,.01), c='black')

plt.xlabel('Max Probability', fontsize = 16)
plt.ylabel('Accuracy', fontsize = 16)
plt.grid()
plt.legend()
plt.title("CIFAR-100, VGG-16", fontsize=14)
#plt.savefig('../plots/cifar100_calibration_1219.eps')
# Out:
# Text(0.5,1,'CIFAR-100, VGG-16')

# %% [markdown]
# #### Temperature Scaling

# %%
swa = np.load('../unc_files/c100/vgg/swag/val_unc_swa.npz')
sgd = np.load('../unc_files/c100/vgg/swag/val_unc_sgd.npz')

# %%
T_swa, rescaled_swa = optimal_temp_scale(swa["predictions"], swa["targets"])
T_sgd, rescaled_sgd = optimal_temp_scale(sgd["predictions"], sgd["targets"])
# Out:
# Before temperature - NLL: 1.409
# After temperature - NLL: 1.185
# Before temperature - NLL: 1.804
# ../experiments/uncertainty/temp_scaling.py:35: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return T.item(), F.softmax(logits / T).data.numpy()
# After temperature - NLL: nan

# %%
swa = np.load('../unc_files/c100/vgg/swag/unc_swa.npz')
sgd = np.load('../unc_files/c100/vgg/swag/unc_sgd.npz')
T_sgd = 1
rescaled_swa = rescale_temp(swa["predictions"], T_swa)
rescaled_sgd = rescale_temp(swa["predictions"], T_sgd)
# Out:
# ../experiments/uncertainty/temp_scaling.py:38: RuntimeWarning: divide by zero encountered in log
#   logits = np.log(probs_arr)

# %%
with_titles = False
print("Accuracy")
if with_titles:
    print("SGD: ", end="")
print(np.mean(np.argmax(sgd["predictions"], axis=1) == sgd["targets"]))
if with_titles:
    print("SWA: ", end="")
print(np.mean(np.argmax(swa["predictions"], axis=1) == swa["targets"]))
if with_titles:
    print("SWAG-Diag: ", end="")
print(np.mean(np.argmax(swag["predictions"], axis=1) == swag["targets"]))
if with_titles:
    print("SWAG-Cov x 0.5: ", end="")
print(np.mean(np.argmax(swag_cov05["predictions"], axis=1) == swag_cov05["targets"]))
if with_titles:
    print("Dropout: ", end="")
print(np.mean(np.argmax(drop["predictions"], axis=1) == drop["targets"]))
if with_titles:
    print("SWA-Dropout: ", end="")
print(np.mean(np.argmax(swa_drop["predictions"], axis=1) == swa_drop["targets"]))
if with_titles:
    print("SGD-Temp: ", end="")
print("-")
if with_titles:
    print("SWA-Temp: ", end="")
print("-")
if with_titles:
    print("KFAC-Laplace: ", end="")
print(np.mean(np.argmax(laplace["predictions"], axis=1) == laplace["targets"]))
print()
print("ECE")
if with_titles:
    print("SGD: ", end="") 
print("%.3f"%(ece_loss(outputs=sgd["predictions"], labels=sgd["targets"])))
if with_titles:
    print("SWA: ", end="") 
print("%.3f"%(ece_loss(outputs=swa["predictions"], labels=swa["targets"])))
if with_titles:
    print("SWAG-Diag: ", end="") 
print("%.3f"%(ece_loss(outputs=swag["predictions"], labels=swag["targets"])))
if with_titles:
    print("SWAG-Cov x 0.5: ", end="") 
print("%.3f"%(ece_loss(outputs=swag_cov05["predictions"], labels=swag_cov05["targets"])))
if with_titles:
    print("Dropout: ", end="") 
print("%.3f"%(ece_loss(outputs=drop["predictions"], labels=drop["targets"])))
if with_titles:
    print("SWA-Dropout: ", end="") 
print("%.3f"%(ece_loss(outputs=swa_drop["predictions"], labels=swa_drop["targets"])))
if with_titles:
    print("SGD-Temp: ", end="")
print("%.3f"%(ece_loss(outputs=rescaled_sgd, labels=swa_drop["targets"])))
if with_titles:
    print("SWA-Temp: ", end="")
print("%.3f"%(ece_loss(outputs=rescaled_swa, labels=swa_drop["targets"])))
if with_titles:
    print("KFAC-Laplace: ", end="") 
print("%.3f"%(ece_loss(outputs=laplace["predictions"], labels=laplace["targets"])))
print()
print("NLL")
if with_titles:
    print("SGD: ", end="") 
print("%.3f"%(NLL(outputs=sgd["predictions"], labels=sgd["targets"])))
if with_titles:
    print("SWA: ", end="") 
print("%.3f"%(NLL(outputs=swa["predictions"], labels=swa["targets"])))
if with_titles:
    print("SWAG-Diag: ", end="") 
print("%.3f"%(NLL(outputs=swag["predictions"], labels=swag["targets"])))
if with_titles:
    print("SWAG-Cov x 0.5: ", end="") 
print("%.3f"%(NLL(outputs=swag_cov05["predictions"], labels=swag_cov05["targets"])))
if with_titles:
    print("Dropout: ", end="") 
print("%.3f"%(NLL(outputs=drop["predictions"], labels=drop["targets"])))
if with_titles:
    print("SWA-Dropout: ", end="") 
print("%.3f"%(NLL(outputs=swa_drop["predictions"], labels=swa_drop["targets"])))
if with_titles:
    print("SGD-Temp: ", end="")
print("%.3f"%(NLL(outputs=rescaled_sgd, labels=swa_drop["targets"])))
if with_titles:
    print("SWA-Temp: ", end="")
print("%.3f"%(NLL(outputs=rescaled_swa, labels=swa_drop["targets"])))
if with_titles:
    print("KFAC-Laplace: ", end="") 
print("%.3f"%(NLL(outputs=laplace["predictions"], labels=laplace["targets"])))
print()
# Out:
# Accuracy
# 0.7299
# 0.7397
# 0.7462
# 0.7483
# 0.7159
# 0.7269
# -
# -
# 0.729
#
# ECE
# 0.185
# 0.157
# 0.084
# 0.044
# 0.087
# 0.090
# 0.157
# 0.033
# 0.137
#
# NLL
# 17318.235
# 12812.515
# 10109.145
# 9420.118
# 11953.627
# 11197.413
# 12812.515
# 10475.780
# 14031.224

# %% [markdown]
# ### WRN

# %%
swag_cov = np.load('../unc_files/c100/wrn/swag/unc_cov.npz')
swag_cov05 = np.load('../unc_files/c100/wrn/swag/unc_cov_scale05.npz')
swag = np.load('../unc_files/c100/wrn/swag/unc.npz')
swa = np.load('../unc_files/c100/wrn/swag/unc_swa.npz')
sgd = np.load('../unc_files/c100/wrn/swag/unc_sgd.npz')
drop = np.load('../unc_files/c100/wrn/swag/unc_drop.npz')
swag_drop = np.load('../unc_files/c100/wrn/swag/unc_swagdrop.npz')
swa_drop = np.load('../unc_files/c100/wrn/swag/unc_swadrop.npz')
# swag_drop = np.load('../unc_files/c100/wrn/swag/unc_swagdrop001.npz')
# swa_drop = np.load('../unc_files/c100/wrn/swag/unc_swadrop001.npz')

# %%
print("Accuracy")
print("SWAG-Diag:", np.mean(np.argmax(swag["predictions"], axis=1) == swag["targets"]))
print("SWAG-Cov:", np.mean(np.argmax(swag_cov["predictions"], axis=1) == swag_cov["targets"]))
print("SWAG-Cov x 0.5:", np.mean(np.argmax(swag_cov05["predictions"], axis=1) == swag_cov05["targets"]))
print("SWA:", np.mean(np.argmax(swa["predictions"], axis=1) == swa["targets"]))
print("SGD:", np.mean(np.argmax(sgd["predictions"], axis=1) == sgd["targets"]))
print("Dropout:", np.mean(np.argmax(drop["predictions"], axis=1) == drop["targets"]))
print("SWAG+Dropout:", np.mean(np.argmax(swag_drop["predictions"], axis=1) == swag_drop["targets"]))
print("SWA+Dropout:", np.mean(np.argmax(swa_drop["predictions"], axis=1) == swa_drop["targets"]))
print()
print("ECE")
print("SWAG-Diag:", ece_loss(outputs=swag["predictions"], labels=swag["targets"]))
print("SWAG-Cov:", ece_loss(outputs=swag_cov["predictions"], labels=swag_cov["targets"]))
print("SWAG-Cov x 0.5:", ece_loss(outputs=swag_cov05["predictions"], labels=swag_cov05["targets"]))
print("SWA:", ece_loss(outputs=swa["predictions"], labels=swa["targets"]))
print("SGD:", ece_loss(outputs=sgd["predictions"], labels=sgd["targets"]))
print("Dropout:", ece_loss(outputs=drop["predictions"], labels=drop["targets"]))
print("SWAG+Dropout:", ece_loss(outputs=swag_drop["predictions"], labels=swag_drop["targets"]))
print("SWA+Dropout:", ece_loss(outputs=swa_drop["predictions"], labels=swa_drop["targets"]))
print()
print("NLL")
print("SWAG-Diag:", NLL(outputs=swag["predictions"], labels=swag["targets"]))
print("SWAG-Cov:", NLL(outputs=swag_cov["predictions"], labels=swag_cov["targets"]))
print("SWAG-Cov x 0.5:", NLL(outputs=swag_cov05["predictions"], labels=swag_cov05["targets"]))
print("SWA:", NLL(outputs=swa["predictions"], labels=swa["targets"]))
print("SGD:", NLL(outputs=sgd["predictions"], labels=sgd["targets"]))
print("Dropout:", NLL(outputs=drop["predictions"], labels=drop["targets"]))
print("SWAG+Dropout:", NLL(outputs=swag_drop["predictions"], labels=swag_drop["targets"]))
print("SWA+Dropout:", NLL(outputs=swa_drop["predictions"], labels=swa_drop["targets"]))
# Out:
# Accuracy
# SWAG-Diag: 0.8245
# SWAG-Cov: 0.8107
# SWAG-Cov x 0.5: 0.8206
# SWA: 0.8262
# SGD: 0.8061
# Dropout: 0.8113
# SWAG+Dropout: 0.8221
# SWA+Dropout: 0.823
#
# ECE
# SWAG-Diag: 0.029730124820010882
# SWAG-Cov: 0.11868338186570514
# SWAG-Cov x 0.5: 0.01297095658431355
# SWA: 0.06540706374049188
# SGD: 0.0474557838983834
# Dropout: 0.03892209709166867
# SWAG+Dropout: 0.018593890754576157
# SWA+Dropout: 0.055073931837299146
#
# NLL
# SWAG-Diag: 6118.855586815227
# SWAG-Cov: 7265.489899230137
# SWAG-Cov x 0.5: 6083.509712906252
# SWA: 6635.4720563024075
# SGD: 8041.556481904021
# Dropout: 7532.6235383928915
# SWAG+Dropout: 6128.476523235352
# SWA+Dropout: 6436.886666148677

# %%
#plt.xscale('log')


acc, bins = compute_accuracy_by_entropy(np.max(swag_cov['predictions'],1), 
                                        np.argmax(swag_cov['predictions'],1), 
                                        swag_cov['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWAG-Cov')

acc, bins = compute_accuracy_by_entropy(np.max(swag_cov05['predictions'],1), 
                                        np.argmax(swag_cov05['predictions'],1), 
                                        swag_cov05['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, '--b', label='SWAG-Cov x 0.5')

acc, bins = compute_accuracy_by_entropy(np.max(swag['predictions'],1), 
                                        np.argmax(swag['predictions'],1), 
                                        swag['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWAG-Diagonal')

acc, bins = compute_accuracy_by_entropy(np.max(swa['predictions'],1), 
                                        np.argmax(swa['predictions'],1), 
                                        swa['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWA')
acc, bins = compute_accuracy_by_entropy(np.max(sgd['predictions'],1), 
                                        np.argmax(sgd['predictions'],1), 
                                        sgd['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SGD')

acc, bins = compute_accuracy_by_entropy(np.max(drop['predictions'],1), 
                                        np.argmax(drop['predictions'],1), 
                                        drop['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, '--k*', label='Dropout')

acc, bins = compute_accuracy_by_entropy(np.max(swag_drop['predictions'],1), 
                                        np.argmax(swag_drop['predictions'],1), 
                                        swag_drop['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, '--*', color="orange", label='SWAG+Dropout')

acc, bins = compute_accuracy_by_entropy(np.max(swa_drop['predictions'],1), 
                                        np.argmax(swa_drop['predictions'],1), 
                                        swa_drop['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, '--*', color="green", label='SWA+Dropout')

plt.plot(np.arange(0.1,1.01,.01), np.arange(0.1,1.01,.01), c='black')

plt.xlabel('Max Probability', fontsize = 16)
plt.ylabel('Accuracy', fontsize = 16)
plt.grid()
plt.legend()
plt.title("CIFAR-100, WRN", fontsize=18)
#plt.savefig('../plots/cifar100_calibration_1219.eps')
# Out:
# Text(0.5,1,'CIFAR-100, WRN')

# %% [markdown]
# #### Temperature scaling

# %%
swa = np.load('../unc_files/c100/wrn/swag/val_swa_unc.npz')
sgd = np.load('../unc_files/c100/wrn/swag/val_sgd_unc.npz')

# %%
T_swa, rescaled_swa = optimal_temp_scale(swa["predictions"], swa["targets"])
T_sgd, rescaled_sgd = optimal_temp_scale(sgd["predictions"], sgd["targets"])
# Out:
# Before temperature - NLL: 0.728
# After temperature - NLL: 0.669
# Before temperature - NLL: 0.838
# ../experiments/uncertainty/temp_scaling.py:35: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return T.item(), F.softmax(logits / T).data.numpy()
# After temperature - NLL: 0.838

# %%
#plt.xscale('log')


acc, bins = compute_accuracy_by_entropy(np.max(swa['predictions'],1), 
                                        np.argmax(swa['predictions'],1), 
                                        swa['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWA')

acc, bins = compute_accuracy_by_entropy(np.max(rescaled_swa,1), 
                                        np.argmax(rescaled_swa,1), 
                                        swa['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWA-rescaled')

acc, bins = compute_accuracy_by_entropy(np.max(sgd['predictions'],1), 
                                        np.argmax(sgd['predictions'],1), 
                                        sgd['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SGD')

acc, bins = compute_accuracy_by_entropy(np.max(rescaled_sgd,1), 
                                        np.argmax(rescaled_sgd,1), 
                                        sgd['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SGD-rescaled')

plt.plot(np.arange(0.1,1.01,.01), np.arange(0.1,1.01,.01), c='black')

plt.xlabel('Max Probability', fontsize = 16)
plt.ylabel('Accuracy', fontsize = 16)
plt.grid()
plt.legend()
plt.title("CIFAR-100 Validation, WRN", fontsize=18)
#plt.savefig('../plots/cifar100_calibration_1219.eps')
# Out:
# Text(0.5,1,'CIFAR-100 Validation, WRN')

# %%
swa = np.load('../unc_files/c100/wrn/swag/unc_swa.npz')
sgd = np.load('../unc_files/c100/wrn/swag/unc_sgd.npz')

# %%
rescaled_swa = rescale_temp(swa["predictions"], T_swa)
rescaled_sgd = rescale_temp(swa["predictions"], T_sgd)

# %%
print("ECE")
print("SWA-Temp:", ece_loss(outputs=rescaled_swa, labels=swa["targets"]))
print("SGD-Temp:", ece_loss(outputs=rescaled_sgd, labels=sgd["targets"]))
print()
print("NLL")
print("SWA-Temp:", NLL(outputs=rescaled_swa, labels=swa["targets"]))
print("SGD-Temp:", NLL(outputs=rescaled_sgd, labels=sgd["targets"]))
# Out:
# ECE
# SWA-Temp: 0.0338575254843263
# SGD-Temp: 0.07018516003125727
#
# NLL
# SWA-Temp: 6298.054412401095
# SGD-Temp: 6765.435229457958

# %%
with_titles = False
print("Accuracy")
if with_titles:
    print("SGD: ", end="")
print(np.mean(np.argmax(sgd["predictions"], axis=1) == sgd["targets"]))
if with_titles:
    print("SWA: ", end="")
print(np.mean(np.argmax(swa["predictions"], axis=1) == swa["targets"]))
if with_titles:
    print("SWAG-Diag: ", end="")
print(np.mean(np.argmax(swag["predictions"], axis=1) == swag["targets"]))
if with_titles:
    print("SWAG-Cov x 0.5: ", end="")
print(np.mean(np.argmax(swag_cov05["predictions"], axis=1) == swag_cov05["targets"]))
if with_titles:
    print("Dropout: ", end="")
print(np.mean(np.argmax(drop["predictions"], axis=1) == drop["targets"]))
if with_titles:
    print("SWA-Dropout: ", end="")
print(np.mean(np.argmax(swa_drop["predictions"], axis=1) == swa_drop["targets"]))
if with_titles:
    print("SGD-Temp: ", end="")
print("-")
if with_titles:
    print("SWA-Temp: ", end="")
print("-")
if with_titles:
    print("KFAC-Laplace: ", end="")
#print(np.mean(np.argmax(laplace["predictions"], axis=1) == laplace["targets"]))
print("-")
print()
print("ECE")
if with_titles:
    print("SGD: ", end="") 
print("%.3f"%(ece_loss(outputs=sgd["predictions"], labels=sgd["targets"])))
if with_titles:
    print("SWA: ", end="") 
print("%.3f"%(ece_loss(outputs=swa["predictions"], labels=swa["targets"])))
if with_titles:
    print("SWAG-Diag: ", end="") 
print("%.3f"%(ece_loss(outputs=swag["predictions"], labels=swag["targets"])))
if with_titles:
    print("SWAG-Cov x 0.5: ", end="") 
print("%.3f"%(ece_loss(outputs=swag_cov05["predictions"], labels=swag_cov05["targets"])))
if with_titles:
    print("Dropout: ", end="") 
print("%.3f"%(ece_loss(outputs=drop["predictions"], labels=drop["targets"])))
if with_titles:
    print("SWA-Dropout: ", end="") 
print("%.3f"%(ece_loss(outputs=swa_drop["predictions"], labels=swa_drop["targets"])))
if with_titles:
    print("SGD-Temp: ", end="")
print("%.3f"%(ece_loss(outputs=rescaled_sgd, labels=swa_drop["targets"])))
if with_titles:
    print("SWA-Temp: ", end="")
print("%.3f"%(ece_loss(outputs=rescaled_swa, labels=swa_drop["targets"])))
if with_titles:
    print("KFAC-Laplace: ", end="") 
# print("%.3f"%(ece_loss(outputs=laplace["predictions"], labels=laplace["targets"])))
print("-")
print()
print("NLL")
if with_titles:
    print("SGD: ", end="") 
print("%.3f"%(NLL(outputs=sgd["predictions"], labels=sgd["targets"])))
if with_titles:
    print("SWA: ", end="") 
print("%.3f"%(NLL(outputs=swa["predictions"], labels=swa["targets"])))
if with_titles:
    print("SWAG-Diag: ", end="") 
print("%.3f"%(NLL(outputs=swag["predictions"], labels=swag["targets"])))
if with_titles:
    print("SWAG-Cov x 0.5: ", end="") 
print("%.3f"%(NLL(outputs=swag_cov05["predictions"], labels=swag_cov05["targets"])))
if with_titles:
    print("Dropout: ", end="") 
print("%.3f"%(NLL(outputs=drop["predictions"], labels=drop["targets"])))
if with_titles:
    print("SWA-Dropout: ", end="") 
print("%.3f"%(NLL(outputs=swa_drop["predictions"], labels=swa_drop["targets"])))
if with_titles:
    print("SGD-Temp: ", end="")
print("%.3f"%(NLL(outputs=rescaled_sgd, labels=swa_drop["targets"])))
if with_titles:
    print("SWA-Temp: ", end="")
print("%.3f"%(NLL(outputs=rescaled_swa, labels=swa_drop["targets"])))
if with_titles:
    print("KFAC-Laplace: ", end="") 
# print("%.3f"%(NLL(outputs=laplace["predictions"], labels=laplace["targets"])))
print("-")
print()
# Out:
# Accuracy
# 0.8061
# 0.8262
# 0.8245
# 0.8206
# 0.8113
# 0.823
# -
# -
# -
#
# ECE
# 0.047
# 0.065
# 0.030
# 0.013
# 0.039
# 0.055
# 0.070
# 0.034
# -
#
# NLL
# 8041.556
# 6635.472
# 6118.856
# 6083.510
# 7532.624
# 6436.887
# 6765.435
# 6298.054
# -

# %% [markdown]
# ### ResNet-110

# %%
swag_cov = np.load('../unc_files/c100/resnet110/swag/unc_cov.npz')
swag_cov05 = np.load('../unc_files/c100/resnet110/swag/unc_cov_scale05.npz')
swag = np.load('../unc_files/c100/resnet110/swag/unc.npz')
swa = np.load('../unc_files/c100/resnet110/swag/unc_swa.npz')
sgd = np.load('../unc_files/c100/resnet110/swag/unc_sgd.npz')

# %%
print("Accuracy")
print("SWAG-Diag:", np.mean(np.argmax(swag["predictions"], axis=1) == swag["targets"]))
print("SWAG-Cov:", np.mean(np.argmax(swag_cov["predictions"], axis=1) == swag_cov["targets"]))
print("SWAG-Cov x 0.5:", np.mean(np.argmax(swag_cov05["predictions"], axis=1) == swag_cov05["targets"]))
print("SWA:", np.mean(np.argmax(swa["predictions"], axis=1) == swa["targets"]))
print("SGD:", np.mean(np.argmax(sgd["predictions"], axis=1) == sgd["targets"]))
print()
print("ECE")
print("SWAG-Diag:", ece_loss(outputs=swag["predictions"], labels=swag["targets"]))
print("SWAG-Cov:", ece_loss(outputs=swag_cov["predictions"], labels=swag_cov["targets"]))
print("SWAG-Cov x 0.5:", ece_loss(outputs=swag_cov05["predictions"], labels=swag_cov05["targets"]))
print("SWA:", ece_loss(outputs=swa["predictions"], labels=swa["targets"]))
print("SGD:", ece_loss(outputs=sgd["predictions"], labels=sgd["targets"]))
print()
print("NLL")
print("SWAG-Diag:", NLL(outputs=swag["predictions"], labels=swag["targets"]))
print("SWAG-Cov:", NLL(outputs=swag_cov["predictions"], labels=swag_cov["targets"]))
print("SWAG-Cov x 0.5:", NLL(outputs=swag_cov05["predictions"], labels=swag_cov05["targets"]))
print("SWA:", NLL(outputs=swa["predictions"], labels=swa["targets"]))
print("SGD:", NLL(outputs=sgd["predictions"], labels=sgd["targets"]))
# Out:
# Accuracy
# SWAG-Diag: 0.7934
# SWAG-Cov: 0.7761
# SWAG-Cov x 0.5: 0.7909
# SWA: 0.7932
# SGD: 0.7794
#
# ECE
# SWAG-Diag: 0.015803552492547775
# SWAG-Cov: 0.17039923710908117
# SWAG-Cov x 0.5: 0.05065014897863836
# SWA: 0.07946868824660779
# SGD: 0.10189417425543065
#
# NLL
# SWAG-Diag: 7148.578580625064
# SWAG-Cov: 9094.748639576168
# SWAG-Cov x 0.5: 7351.904916771163
# SWA: 7816.327930063768
# SGD: 9790.914572875965

# %%
#plt.xscale('log')


acc, bins = compute_accuracy_by_entropy(np.max(swag_cov['predictions'],1), 
                                        np.argmax(swag_cov['predictions'],1), 
                                        swag_cov['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWAG-Cov')

acc, bins = compute_accuracy_by_entropy(np.max(swag_cov05['predictions'],1), 
                                        np.argmax(swag_cov05['predictions'],1), 
                                        swag_cov05['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, '--y', label='SWAG-Cov x 0.5')

acc, bins = compute_accuracy_by_entropy(np.max(swag['predictions'],1), 
                                        np.argmax(swag['predictions'],1), 
                                        swag['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWAG-Diagonal')

acc, bins = compute_accuracy_by_entropy(np.max(swa['predictions'],1), 
                                        np.argmax(swa['predictions'],1), 
                                        swa['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SWA')

acc, bins = compute_accuracy_by_entropy(np.max(sgd['predictions'],1), 
                                        np.argmax(sgd['predictions'],1), 
                                        sgd['targets'],
                                       bins = np.arange(0.1, 1.05, 0.05))
plt.plot(bins[1:], acc, label='SGD')

plt.plot(np.arange(0.1,1.01,.01), np.arange(0.1,1.01,.01), c='black')

plt.xlabel('Max Probability', fontsize = 16)
plt.ylabel('Accuracy', fontsize = 16)
plt.grid()
plt.legend()
plt.title("CIFAR-100, PreResNet-110", fontsize=18)
#plt.savefig('../plots/cifar100_calibration_1219.eps')
# Out:
# Text(0.5,1,'CIFAR-100, PreResNet-110')

# %% [markdown]
# #### Temperature scaling

# %%
swa = np.load('../unc_files/c100/resnet110/swag/val_unc_swa.npz')
sgd = np.load('../unc_files/c100/resnet110/swag/val_unc_sgd.npz')

# %%
T_swa, rescaled_swa = optimal_temp_scale(swa["predictions"], swa["targets"])
T_sgd, rescaled_sgd = optimal_temp_scale(sgd["predictions"], sgd["targets"])
# Out:
# Before temperature - NLL: 0.774
# After temperature - NLL: 0.715
# Before temperature - NLL: 0.995
# ../experiments/uncertainty/temp_scaling.py:35: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return T.item(), F.softmax(logits / T).data.numpy()
# After temperature - NLL: 1.026

# %%
swa = np.load('../unc_files/c100/resnet110/swag/unc_swa.npz')
sgd = np.load('../unc_files/c100/resnet110/swag/unc_sgd.npz')
rescaled_swa = rescale_temp(swa["predictions"], T_swa)
rescaled_sgd = rescale_temp(swa["predictions"], T_sgd)

# %%
print("ECE")
print("SWA-Temp:", ece_loss(outputs=rescaled_swa, labels=swa["targets"]))
print("SGD-Temp:", ece_loss(outputs=rescaled_sgd, labels=sgd["targets"]))
print()
print("NLL")
print("SWA-Temp:", NLL(outputs=rescaled_swa, labels=swa["targets"]))
print("SGD-Temp:", NLL(outputs=rescaled_sgd, labels=sgd["targets"]))
# Out:
# ECE
# SWA-Temp: 0.035833401585121924
# SGD-Temp: 0.14778524978332352
#
# NLL
# SWA-Temp: 7235.631886609586
# SGD-Temp: 8537.251371538694

# %%
with_titles = False
print("Accuracy")
if with_titles:
    print("SGD: ", end="")
print(np.mean(np.argmax(sgd["predictions"], axis=1) == sgd["targets"]))
if with_titles:
    print("SWA: ", end="")
print(np.mean(np.argmax(swa["predictions"], axis=1) == swa["targets"]))
if with_titles:
    print("SWAG-Diag: ", end="")
print(np.mean(np.argmax(swag["predictions"], axis=1) == swag["targets"]))
if with_titles:
    print("SWAG-Cov x 0.5: ", end="")
print(np.mean(np.argmax(swag_cov05["predictions"], axis=1) == swag_cov05["targets"]))
if with_titles:
    print("Dropout: ", end="")
# print(np.mean(np.argmax(drop["predictions"], axis=1) == drop["targets"]))
print("-")
if with_titles:
    print("SWA-Dropout: ", end="")
# print(np.mean(np.argmax(swa_drop["predictions"], axis=1) == swa_drop["targets"]))
print("-")
if with_titles:
    print("SGD-Temp: ", end="")
print("-")
if with_titles:
    print("SWA-Temp: ", end="")
print("-")
if with_titles:
    print("KFAC-Laplace: ", end="")
#print(np.mean(np.argmax(laplace["predictions"], axis=1) == laplace["targets"]))
print("-")
print()
print("ECE")
if with_titles:
    print("SGD: ", end="") 
print("%.3f"%(ece_loss(outputs=sgd["predictions"], labels=sgd["targets"])))
if with_titles:
    print("SWA: ", end="") 
print("%.3f"%(ece_loss(outputs=swa["predictions"], labels=swa["targets"])))
if with_titles:
    print("SWAG-Diag: ", end="") 
print("%.3f"%(ece_loss(outputs=swag["predictions"], labels=swag["targets"])))
if with_titles:
    print("SWAG-Cov x 0.5: ", end="") 
print("%.3f"%(ece_loss(outputs=swag_cov05["predictions"], labels=swag_cov05["targets"])))
if with_titles:
    print("Dropout: ", end="") 
# print("%.3f"%(ece_loss(outputs=drop["predictions"], labels=drop["targets"])))
print("-")
if with_titles:
    print("SWA-Dropout: ", end="") 
# print("%.3f"%(ece_loss(outputs=swa_drop["predictions"], labels=swa_drop["targets"])))
print("-")
if with_titles:
    print("SGD-Temp: ", end="")
print("%.3f"%(ece_loss(outputs=rescaled_sgd, labels=swa_drop["targets"])))
if with_titles:
    print("SWA-Temp: ", end="")
print("%.3f"%(ece_loss(outputs=rescaled_swa, labels=swa_drop["targets"])))
if with_titles:
    print("KFAC-Laplace: ", end="") 
# print("%.3f"%(ece_loss(outputs=laplace["predictions"], labels=laplace["targets"])))
print("-")
print()
print("NLL")
if with_titles:
    print("SGD: ", end="") 
print("%.3f"%(NLL(outputs=sgd["predictions"], labels=sgd["targets"])))
if with_titles:
    print("SWA: ", end="") 
print("%.3f"%(NLL(outputs=swa["predictions"], labels=swa["targets"])))
if with_titles:
    print("SWAG-Diag: ", end="") 
print("%.3f"%(NLL(outputs=swag["predictions"], labels=swag["targets"])))
if with_titles:
    print("SWAG-Cov x 0.5: ", end="") 
print("%.3f"%(NLL(outputs=swag_cov05["predictions"], labels=swag_cov05["targets"])))
if with_titles:
    print("Dropout: ", end="") 
# print("%.3f"%(NLL(outputs=drop["predictions"], labels=drop["targets"])))
print("-")
if with_titles:
    print("SWA-Dropout: ", end="") 
#print("%.3f"%(NLL(outputs=swa_drop["predictions"], labels=swa_drop["targets"])))
print("-")
if with_titles:
    print("SGD-Temp: ", end="")
print("%.3f"%(NLL(outputs=rescaled_sgd, labels=swa_drop["targets"])))
if with_titles:
    print("SWA-Temp: ", end="")
print("%.3f"%(NLL(outputs=rescaled_swa, labels=swa_drop["targets"])))
if with_titles:
    print("KFAC-Laplace: ", end="") 
# print("%.3f"%(NLL(outputs=laplace["predictions"], labels=laplace["targets"])))
print("-")
print()
# Out:
# Accuracy
# 0.7794
# 0.7932
# 0.7934
# 0.7909
# -
# -
# -
# -
# -
#
# ECE
# 0.102
# 0.079
# 0.016
# 0.051
# -
# -
# 0.148
# 0.036
# -
#
# NLL
# 9790.915
# 7816.328
# 7148.579
# 7351.905
# -
# -
# 8537.251
# 7235.632
# -
